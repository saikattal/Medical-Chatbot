# %%
print("HI!")
# Out:
# HI!

# %%
from langchain.document_loaders import DirectoryLoader, PyPDFLoader

data="C:\\Users\\LENOVO\\Documents\\LLMOPs Projects\\Medical-Chatbot\\data"

loader=DirectoryLoader(data,glob="*.pdf",
                       loader_cls=PyPDFLoader,
                       )

# %%
documents=loader.load()
# Out:
# ...
# Upserted vectors:   0%|          | 0/91 [00:27<?, ?it/s]

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_spliter=RecursiveCharacterTextSplitter(chunk_size=500,
                                            chunk_overlap=20)

text_chunks=text_spliter.split_documents(documents)

# %%
from langchain.embeddings import HuggingFaceEmbeddings

embeddings=HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# c:\Users\LENOVO\anaconda3\envs\medchat\lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
import os
from dotenv import load_dotenv

load_dotenv()

PINECONE_API_KEY=os.environ.get('PINECONE_API_KEY')
PINECONE_API_ENV=os.environ.get('PINECONE_API_ENV')

# %%
import pinecone
from langchain.vectorstores import Pinecone

# Initialize Pinecone
pinecone.init(api_key=PINECONE_API_KEY, environment=PINECONE_API_ENV)

# Create or connect to an existing index
index_name = "medical-bot"

if index_name not in pinecone.list_indexes():
    pinecone.create_index(index_name, dimension=your_embedding_dimension)

index = pinecone.Index(index_name)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\LENOVO\anaconda3\envs\medchat\lib\site-packages\urllib3\connection.py:196, in HTTPConnection._new_conn(self)
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#
# File c:\Users\LENOVO\anaconda3\envs\medchat\lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# ...

# %%
pc.create_index(
    name="medical-bot",
    dimension=4096, # Replace with your model dimensions
    metric="cosine", # Replace with your model metric
    spec=ServerlessSpec(
        cloud="aws",
        region="us-east-1"
    ) 
)

# %%
index = pinecone.Index("medical-bot")

# %%
docsearch=Pinecone.from_existing_index("medical-bot",
                                       embedding=embeddings
                                       )

# %%
text_chunks = [t.page_content for t in text_chunks]

# %%
docsearch.add_texts(text_chunks)
# Out:
# Upserted vectors:   0%|          | 0/91 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\LENOVO\anaconda3\envs\medchat\lib\site-packages\urllib3\connection.py:196, in HTTPConnection._new_conn(self)
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#
# File c:\Users\LENOVO\anaconda3\envs\medchat\lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
# ...

# %%
docsearch=Pinecone.from_texts([t.page_content for t in text_chunks], embeddings, index_name="medical-bot")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\LENOVO\anaconda3\envs\medchat\lib\site-packages\urllib3\connection.py:196, in HTTPConnection._new_conn(self)
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#
# File c:\Users\LENOVO\anaconda3\envs\medchat\lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# ...
